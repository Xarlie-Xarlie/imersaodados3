# %%
import pandas as pd
dados = pd.read_csv("dados_experimentos.zip", compression = 'zip')
dados.head()
# Out:
#              id tratamento  tempo dose      droga     g-0     g-1     g-2  \
# 0  id_000644bb2  com_droga     24   D1  b68db1d53  1.0620  0.5577 -0.2479
# 1  id_000779bfc  com_droga     72   D1  df89a8e5a  0.0743  0.4087  0.2991
# 2  id_000a6266a  com_droga     48   D1  18bb41b2c  0.6280  0.5817  1.5540
# 3  id_0015fd391  com_droga     48   D1  8c7f86626 -0.5138 -0.2491 -0.2656
# 4  id_001626bd3  com_droga     72   D2  7cbed3131 -0.3254 -0.4009  0.9700
#
#       g-3     g-4  ...    c-90    c-91    c-92    c-93    c-94    c-95  \
# 0 -0.6208 -0.1944  ...  0.2862  0.2584  0.8076  0.5523 -0.1912  0.6584
# 1  0.0604  1.0190  ... -0.4265  0.7543  0.4708  0.0230  0.2957  0.4899
# 2 -0.0764 -0.0323  ... -0.7250 -0.6297  0.6103  0.0223 -1.3240 -0.3174
# 3  0.5288  4.0620  ... -2.0990 -0.6441 -5.6300 -1.3780 -0.8632 -1.2880
# 4  0.6919  1.4180  ...  0.0042  0.0048  0.6670  1.0690  0.5523 -0.3031
#
#      c-96    c-97    c-98    c-99
# 0 -0.3981  0.2139  0.3801  0.4176
# ...

# %% [markdown]
# ## Desafio 1: Investigar por que a classe tratamento é tão desbalanceada?

# %%
dados['tratamento'].value_counts(normalize=True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %%
dados[dados['tratamento']=='com_controle'] == dados[dados['droga']=='cacb2b860']
# Out:
#          id  tratamento  tempo  dose  droga   g-0   g-1   g-2   g-3   g-4  \
# 25     True        True   True  True   True  True  True  True  True  True
# 38     True        True   True  True   True  True  True  True  True  True
# 40     True        True   True  True   True  True  True  True  True  True
# 47     True        True   True  True   True  True  True  True  True  True
# 63     True        True   True  True   True  True  True  True  True  True
# ...     ...         ...    ...   ...    ...   ...   ...   ...   ...   ...
# 23729  True        True   True  True   True  True  True  True  True  True
# 23747  True        True   True  True   True  True  True  True  True  True
# 23768  True        True   True  True   True  True  True  True  True  True
# 23793  True        True   True  True   True  True  True  True  True  True
# 23811  True        True   True  True   True  True  True  True  True  True
#
#        ...  c-90  c-91  c-92  c-93  c-94  c-95  c-96  c-97  c-98  c-99
# ...

# %% [markdown]
# A classe tratamento é desbalanceada devido ao teste de um tipo espécifico de droga, do qual apenas a droga 'cacb2b860' é utilizada em controle

# %% [markdown]
# ## Desafio 02: Plotar as 5 últimas linhas da tabela

# %%
dados[-5:]
# Out:
#                  id    tratamento  tempo dose      droga     g-0     g-1  \
# 23809  id_fffb1ceed     com_droga     24   D2  df1d0a5a1  0.1394 -0.0636
# 23810  id_fffb70c0c     com_droga     24   D2  ecf3b6b74 -1.3260  0.3478
# 23811  id_fffc1c3f4  com_controle     48   D2  cacb2b860  0.3942  0.3756
# 23812  id_fffcb9e7c     com_droga     24   D1  8b87a7a83  0.6660  0.2324
# 23813  id_ffffdd77b     com_droga     72   D1  972f41291 -0.8598  1.0240
#
#           g-2     g-3     g-4  ...    c-90    c-91    c-92    c-93    c-94  \
# 23809 -0.1112 -0.5080 -0.4713  ...  0.1969  0.0262 -0.8121  0.3434  0.5372
# 23810 -0.3743  0.9905 -0.7178  ...  0.4286  0.4426  0.0423 -0.3195 -0.8086
# 23811  0.3109 -0.7389  0.5505  ...  0.5409  0.3755  0.7343  0.2807  0.4116
# 23812  0.4392  0.2044  0.8531  ... -0.1105  0.4258 -0.2012  0.1506  1.5230
# 23813 -0.1361  0.7952 -0.3611  ... -3.3890 -1.7450 -6.6300 -4.0950 -7.3860
#
#          c-95    c-96    c-97    c-98    c-99
# ...

# %% [markdown]
# ## Desafio 03: Proporção das classes tratamento.

# %%
dados['tratamento'].value_counts(normalize=True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.bar('com Droga',dados['tratamento'].value_counts(normalize=True)[0], color = 'green', align='center', data=None, width=0.7)
plt.bar('com Tratamento',dados['tratamento'].value_counts(normalize=True)[1], color ='blue',align='center', data=None,width=0.7)
plt.xlabel("Tipo de tratamento", color = 'blue')
plt.ylabel("Porcentagem", color='blue')
plt.title('Análise de Tratamentos',color='blue')
# Out:
# Text(0.5, 1.0, 'Análise de Tratamentos')

# %% [markdown]
# ## Desafio 04: Quantas tipos de drogas foram investigados.

# %%
len(dados['droga'].unique())
# Out:
# 3289

# %% [markdown]
# ## Desafio 05: Procurar na documentação o método query(pandas).

# %% [markdown]
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.query.html

# %%
dados.query('tempo==48')
# Out:
#                  id    tratamento  tempo dose      droga     g-0     g-1  \
# 2      id_000a6266a     com_droga     48   D1  18bb41b2c  0.6280  0.5817
# 3      id_0015fd391     com_droga     48   D1  8c7f86626 -0.5138 -0.2491
# 7      id_0020d0484     com_droga     48   D1  8b87a7a83  0.2711  0.5133
# 8      id_00224bf20     com_droga     48   D1  952b76dfc -0.3014  0.5545
# 9      id_0023f063e     com_droga     48   D2  de7583071 -0.0630  0.2564
# ...             ...           ...    ...  ...        ...     ...     ...
# 23803  id_fff485da4     com_droga     48   D1  f88ceb191  0.4123 -0.1551
# 23805  id_fff6df1c5     com_droga     48   D2  5628cb3ee  1.7380 -1.2900
# 23806  id_fff790a17     com_droga     48   D2  47dd8f190 -0.1150 -0.8037
# 23807  id_fff7e6992     com_droga     48   D1  a28556d51  0.1420 -0.3696
# 23811  id_fffc1c3f4  com_controle     48   D2  cacb2b860  0.3942  0.3756
#
#           g-2     g-3     g-4  ...    c-90    c-91    c-92    c-93    c-94  \
# ...

# %% [markdown]
# ## Desafio 06: Renomear as colunas tirando o hífen.

# %%
colunas = ['id','tratamento','tempo','dose','droga']
for i in range(5,len(dados.columns)):
    colunas.append(dados.columns[i].split('-')[0]+dados.columns[i].split('-')[1])
len(aux),len(colunas)
dados.columns = colunas

# %%
dados
# Out:
#                  id    tratamento  tempo dose      droga      g0      g1  \
# 0      id_000644bb2     com_droga     24   D1  b68db1d53  1.0620  0.5577
# 1      id_000779bfc     com_droga     72   D1  df89a8e5a  0.0743  0.4087
# 2      id_000a6266a     com_droga     48   D1  18bb41b2c  0.6280  0.5817
# 3      id_0015fd391     com_droga     48   D1  8c7f86626 -0.5138 -0.2491
# 4      id_001626bd3     com_droga     72   D2  7cbed3131 -0.3254 -0.4009
# ...             ...           ...    ...  ...        ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  df1d0a5a1  0.1394 -0.0636
# 23810  id_fffb70c0c     com_droga     24   D2  ecf3b6b74 -1.3260  0.3478
# 23811  id_fffc1c3f4  com_controle     48   D2  cacb2b860  0.3942  0.3756
# 23812  id_fffcb9e7c     com_droga     24   D1  8b87a7a83  0.6660  0.2324
# 23813  id_ffffdd77b     com_droga     72   D1  972f41291 -0.8598  1.0240
#
#            g2      g3      g4  ...     c90     c91     c92     c93     c94  \
# ...

# %% [markdown]
# ## Desafio 07: Deixar os gráficos bonitões. (Matplotlib.pyplot)
# feito

# %% [markdown]
# ## Desafio 08: Resumo do que você aprendeu com os dados

# %% [markdown]
# Os dados possuem uma boa correlação, é possível extrair algumas informações de início
# mesmo não tendo conhecimento total dos tipos de drogas que estamos trabalhando

# %% [markdown]
# Temos vários tipos de drogas com duas doses sendo aplicadas por 3 tempos diferentes,
# um em específico está sendo controlada em frequência relativamente baixa.
